# %% [markdown]
# <a href="https://colab.research.google.com/github/arz03/ML_lab_ai601/blob/main/ML_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/find_s.csv')
df
# Out:
#       Time Weather Temperature Company Humidity    Wind Goes
# 0  Morning   Sunny        Warm     Yes     Mild  Strong  Yes
# 1  Evening   Rainy        Cold      No     Mild  Normal   No
# 2  Morning   Sunny    Moderate     Yes   Normal  Normal  Yes
# 3  Evening   Sunny        Cold     Yes     High  Strong  Yes

# %%
h=df.iloc[0].to_list()
h.pop(-1)
h
# Out:
# ['Morning', 'Sunny', 'Warm', 'Yes', 'Mild', 'Strong']

# %%
space=[]
for row in df.iterrows():
  # print(row[1][-1])
  if row[1][-1]=='Yes':
    if row[1][0]!=h[0]:
      h[0]='?'
    if row[1][1]!=h[1]:
      h[1]='?'
    if row[1][2]!=h[2]:
      h[2]='?'
    if row[1][3]!=h[3]:
      h[3]='?'
    if row[1][4]!=h[4]:
      h[4]='?'
    if row[1][5]!=h[5]:
      h[5]='?'
# Out:
# /tmp/ipython-input-1445535108.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[1][-1]=='Yes':
# /tmp/ipython-input-1445535108.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[1][0]!=h[0]:
# /tmp/ipython-input-1445535108.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[1][1]!=h[1]:
# ...

# %%
h
# Out:
# ['?', 'Sunny', '?', 'Yes', '?', '?']
